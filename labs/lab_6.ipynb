# %% [markdown]
# <br> Radley Ciego </br>
# <br> GTECH 73100 </br>
# <br> Assignment 6: Geometry & Spatial Data </br>

# %% [markdown]
# ## Task 1:
# Install the geopandas package

# %%
import geopandas as gpd
import os

# %%
cwd = os.getcwd

# %% [markdown]
# ## Task 2:
# Find and import at least three sets of spatial data as a GeoDataFrame using geopandas. Identify the data type of each column for one dataframe. Export all three into a single geopackage file (geodatabase). Note that the single geopackage file should have three layers inside, not three layers in three separate geopackage files.

# %%
tunisia = gpd.read_file("/Users/radleyciego/GitHub/geocomputation/labs/tun_adm_ins_20221115_shp/tun_admbnda_adm4_ins_20221115.shp")

# %%
tunisia
# Out:
#       Shape_Leng  Shape_Area         ADM4_EN         ADM4_AR ADM4_PCODE  \
# 0       0.055436    0.000151   Sidi Bou Said     سيدي بوسعيد   TN115151
# 1       0.033450    0.000069         Amilcar         أميلكار   TN115152
# 2       0.085394    0.000349  Carthage Byrsa     قرطاج بيرصا   TN115153
# 3       0.099273    0.000189  Carthage Plage   قرطاج الشاطىء   TN115154
# 4       0.016574    0.000016       Le Jasmin       الياسمينة   TN115155
# ...          ...         ...             ...             ...        ...
# 2079    1.567096    0.112522          Gharib            غريب   TN635653
# 2080    0.519129    0.009591         Gueidma           غيدمة   TN635654
# 2081    1.880177    0.201775   Rejim Maatoug      رجيم معتوق   TN635655
# 2082    0.893202    0.045633     El Matrouha        المطروحة   TN635656
# 2083    1.699798    0.108277  Bichni-Edarjin  بشني - الدرجين   TN635657
#
#      ADM4_REF ADM4ALT1EN ADM4ALT2EN ADM4ALT1AR ADM4ALT2AR  ...     ADM1_EN  \
# ...

# %%
# create a variable hosting data types for each column
datatypes = tunisia.dtypes

# %%
datatypes
# Out:
# Shape_Leng     float64
# Shape_Area     float64
# ADM4_EN         object
# ADM4_AR         object
# ADM4_PCODE      object
# ADM4_REF        object
# ADM4ALT1EN      object
# ADM4ALT2EN      object
# ADM4ALT1AR      object
# ADM4ALT2AR      object
# ADM3_EN         object
# ADM3_AR         object
# ADM3_PCODE      object
# ADM2_EN         object
# ADM2_AR         object
# ADM2_PCODE      object
# ADM1_EN         object
# ADM1_AR         object
# ADM1_PCODE      object
# ADM0_EN         object
# ADM0_AR         object
# ADM0_PCODE      object
# date            object
# validOn         object
# validTo         object
# geometry      geometry
# dtype: object

# %%
tunisia.plot()
# Out:
# <AxesSubplot: >

# %%
morocco = gpd.read_file('geoBoundaries-MAR-ADM2.geojson')
morocco
# Out:
#                                      shapeName shapeISO  \
# 0         Province de Khémisset إقليم الخميسات
# 1                              Rhamna Province
# 2   Province de Sidi Slimane إقليم سيدي سليمان
# 3           Province de Kenitra إقليم القنيطرة
# 4                           Taroudant Province
# ..                                         ...      ...
# 70             Province d'Aousserd إقليم أوسرد
# 71                    Prefecture of Casablanca
# 72                          Berrechid Province
# 73                          El Jadida Province
# 74                      Oued Ed-Dahab Province
#
#                     shapeID shapeGroup shapeType  \
# 0   96644757B24539393832458        MAR      ADM2
# 1   96644757B47362388588228        MAR      ADM2
# 2   96644757B64432809888793        MAR      ADM2
# 3   96644757B75114434411307        MAR      ADM2
# 4   96644757B78868216742222        MAR      ADM2
# ..                      ...        ...       ...
# ...

# %%
datatypes = morocco.dtypes

# %%
datatypes
# Out:
# shapeName       object
# shapeISO        object
# shapeID         object
# shapeGroup      object
# shapeType       object
# geometry      geometry
# dtype: object

# %%
morocco.plot()
# Out:
# <AxesSubplot: >

# %%
egypt = gpd.read_file('/Users/radleyciego/GitHub/geocomputation/labs/hotosm_egy_railways_gpkg/hotosm_egy_railways.gpkg')

# %%
egypt
# Out:
#           osm_id addr:city addr:full  name   ele  railway source layer  \
# 0        7849688      None      None  None  None     rail   None  None
# 1       24821627      None      None  None  None     rail   None  None
# 2       24821798      None      None  None  None     rail   None  None
# 3       25191035      None      None  None  None     rail   None     1
# 4       25191065      None      None  None  None     rail   None  None
# ...          ...       ...       ...   ...   ...      ...    ...   ...
# 1682  1050965876      None      None  None  None     rail   None  None
# 1683  1050965877      None      None  None  None     rail   None  None
# 1684  1050965878      None      None  None  None     rail   None     1
# 1685  1050965879      None      None  None  None     rail   None  None
# 1686  1054875901      None      None  None  None  station   None  None
#
#      operator:type                                           geometry
# ...

# %%
datatypes = egypt.dtypes

# %%
datatypes
# Out:
# osm_id              int64
# addr:city          object
# addr:full          object
# name               object
# ele                object
# railway            object
# source             object
# layer              object
# operator:type      object
# geometry         geometry
# dtype: object

# %%
egypt.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Task 3:
# Use basic web mapping methods in geopandas to visualize the data. You are ecouraged to use plotly.express to draw these maps.
